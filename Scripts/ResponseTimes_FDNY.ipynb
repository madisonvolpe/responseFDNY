# %%
#import pandas as pd 
import pandas as pd 

#read in data
fdny_df = pd.read_csv('/Users/madisonvolpe/documents/Projects/FDNY_ResponseTimes/FDNY_Monthly_Response_Times.csv')

# %%
#inspect first five rows
fdny_df.head()
# Out:
#   YEARMONTH        INCIDENTCLASSIFICATION INCIDENTBOROUGH  INCIDENTCOUNT  \
# 0   2009/07  All Fire/Emergency Incidents        Citywide          40850
# 1   2009/07  All Fire/Emergency Incidents       Manhattan          10709
# 2   2009/07  All Fire/Emergency Incidents           Bronx           8137
# 3   2009/07  All Fire/Emergency Incidents   Staten Island           2205
# 4   2009/07  All Fire/Emergency Incidents        Brooklyn          11505
#
#   AVERAGERESPONSETIME
# 0               04:27
# 1               04:32
# 2               04:37
# 3               04:45
# 4               04:01

# %%
fdny_df.info() #inspecting data types of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4368 entries, 0 to 4367
# Data columns (total 5 columns):
# YEARMONTH                 4368 non-null object
# INCIDENTCLASSIFICATION    4368 non-null object
# INCIDENTBOROUGH           4368 non-null object
# INCIDENTCOUNT             4368 non-null int64
# AVERAGERESPONSETIME       4368 non-null object
# dtypes: int64(1), object(4)
# memory usage: 170.7+ KB

# %%
#Now we will filter for those in YEARMONTH with FY distinction
fiscalyear = fdny_df.YEARMONTH.str.contains('^FY')
fdny_df_fil = fdny_df[fiscalyear]

#We will also filter for "All Fire/Emergency Incidents"
emer_inc = fdny_df.INCIDENTCLASSIFICATION.str.contains("All Fire/Emergency Incidents")
fdny_df_fil = fdny_df_fil[emer_inc]
# Out:
# /Users/madisonvolpe/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
#check the unique valaues of YEARMONTH and INCIDENTCLASSIFICATION columns 
print(fdny_df_fil.YEARMONTH.unique())
print(fdny_df_fil.INCIDENTCLASSIFICATION.unique())
# Out:
# ['FY 2010' 'FY 2011' 'FY 2012' 'FY 2013' 'FY 2014' 'FY 2015' 'FY 2016'
#  'FY 2017']
# ['All Fire/Emergency Incidents']

# %%
#convert AVERAGERESPONSETIME to time 
fdny_df_fil['AVERAGERESPONSETIME']=pd.to_datetime(fdny_df_fil['AVERAGERESPONSETIME'], format='%M:%S')
fdny_df_fil
# Out:
#      YEARMONTH        INCIDENTCLASSIFICATION INCIDENTBOROUGH  INCIDENTCOUNT  \
# 4032   FY 2010  All Fire/Emergency Incidents        Citywide         489354
# 4033   FY 2010  All Fire/Emergency Incidents       Manhattan         125685
# 4034   FY 2010  All Fire/Emergency Incidents           Bronx          98322
# 4035   FY 2010  All Fire/Emergency Incidents   Staten Island          27893
# 4036   FY 2010  All Fire/Emergency Incidents        Brooklyn         137657
# 4037   FY 2010  All Fire/Emergency Incidents          Queens          99797
# 4074   FY 2011  All Fire/Emergency Incidents        Citywide         493146
# 4075   FY 2011  All Fire/Emergency Incidents       Manhattan         128195
# 4076   FY 2011  All Fire/Emergency Incidents           Bronx          97750
# 4077   FY 2011  All Fire/Emergency Incidents   Staten Island          25857
# 4078   FY 2011  All Fire/Emergency Incidents        Brooklyn         139278
# 4079   FY 2011  All Fire/Emergency Incidents          Queens         102066
# 4158 1900-01-01 00:04:46
# 4159 1900-01-01 00:04:51
# 4160 1900-01-01 00:04:55
# 4161 1900-01-01 00:04:59
# 4162 1900-01-01 00:04:20
# 4163 1900-01-01 00:05:04
# 4200 1900-01-01 00:04:46
# 4201 1900-01-01 00:04:58
# 4202 1900-01-01 00:05:01
# 4203 1900-01-01 00:04:56
# 4204 1900-01-01 00:04:16
# 4205 1900-01-01 00:04:55
# 4242 1900-01-01 00:04:50
# 4243 1900-01-01 00:05:03
# 4244 1900-01-01 00:05:03
# 4245 1900-01-01 00:04:54
# 4246 1900-01-01 00:04:19
# 4247 1900-01-01 00:05:02
# 4284 1900-01-01 00:04:52
# 4285 1900-01-01 00:05:12
# 4286 1900-01-01 00:05:05
# 4287 1900-01-01 00:04:49
# 4288 1900-01-01 00:04:19
# 4289 1900-01-01 00:05:02
# 4326 1900-01-01 00:04:56
# 4327 1900-01-01 00:05:16
# 4328 1900-01-01 00:05:14
# 4329 1900-01-01 00:04:44
# 4330 1900-01-01 00:04:22
# 4331 1900-01-01 00:05:05

# %%
fdny_df_fil.groupby('INCIDENTBOROUGH').agg({'INCIDENTCOUNT': 'mean'})
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-138-161b2faf1423> in <module>()
# ----> 1 fdny_df_fil.groupby('INCIDENTBOROUGH').agg({'INCIDENTCOUNT': 'mean', 'AVERAGERESPONSETIME': 'mean'})
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4656         axis=''))
#    4657     def aggregate(self, arg, *args, **kwargs):
# -> 4658         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4659
#    4660     agg = aggregate
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4087
#    4088         _level = kwargs.pop('_level', None)
# -> 4089         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    4090         if how is None:
#    4091             return result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     488
#     489                 try:
# --> 490                     result = _agg(arg, _agg_1dim)
#     491                 except SpecificationError:
#     492
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _agg(arg, func)
#     439                 result = compat.OrderedDict()
#     440                 for fname, agg_how in compat.iteritems(arg):
# --> 441                     result[fname] = func(fname, agg_how)
#     442                 return result
#     443
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     422                     raise SpecificationError("nested dictionary is ambiguous "
#     423                                              "in aggregation")
# --> 424                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     425
#     426             def _agg_2dim(name, how):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3477         _level = kwargs.pop('_level', None)
#    3478         if isinstance(func_or_funcs, compat.string_types):
# -> 3479             return getattr(self, func_or_funcs)(*args, **kwargs)
#    3480
#    3481         if isinstance(func_or_funcs, collections.Iterable):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
# -> 1306             return self._cython_agg_general('mean', **kwargs)
#    1307         except GroupByError:
#    1308             raise
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1054
#    1055         if len(output) == 0:
# -> 1056             raise DataError('No numeric types to aggregate')
#    1057
#    1058         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate
